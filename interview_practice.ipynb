# %% [markdown]
# <a href="https://colab.research.google.com/github/nikkijha97/Interview-question/blob/main/interview_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import random
from datetime import datetime, timedelta

# Parameters for data generation
num_records = 1000
num_stores = 5
num_products = 20
num_customers = 100

# Generate sample data
store_ids = [f'ST{str(i).zfill(2)}' for i in range(1, num_stores + 1)]
product_ids = [f'PR{str(i).zfill(3)}' for i in range(1, num_products + 1)]
customer_ids = [f'CUST{str(i).zfill(3)}' for i in range(1, num_customers + 1)]

# Generate random dates within a specific range
start_date = datetime(2023, 1, 1)
end_date = datetime(2023, 12, 31)
date_range = (end_date - start_date).days
# Create the DataFrame
data = {
    'Date': [(start_date + timedelta(days=random.randint(0, date_range))).strftime('%Y-%m-%d') for _ in range(num_records)],
    'Store_ID': [random.choice(store_ids) for _ in range(num_records)],
    'Product_ID': [random.choice(product_ids) for _ in range(num_records)],
    'Quantity': [random.randint(1, 10) for _ in range(num_records)],
    'Unit_Price': [round(random.uniform(5.0, 100.0), 2) for _ in range(num_records)],
    'Customer_ID': [random.choice(customer_ids) for _ in range(num_records)]
}

# Create DataFrame
sales_data = pd.DataFrame(data)

sales_data
# Out:
#            Date Store_ID Product_ID  Quantity  Unit_Price Customer_ID
# 0    2023-10-25     ST04      PR001         2        9.49     CUST038
# 1    2023-01-19     ST01      PR009         4       65.24     CUST013
# 2    2023-11-17     ST04      PR011         1       96.37     CUST084
# 3    2023-12-18     ST04      PR002         7       28.63     CUST018
# 4    2023-01-08     ST03      PR011         3       63.63     CUST047
# ..          ...      ...        ...       ...         ...         ...
# 995  2023-10-25     ST03      PR010         9       57.26     CUST085
# 996  2023-03-08     ST01      PR008         4       22.71     CUST078
# 997  2023-01-15     ST04      PR020         2       72.99     CUST036
# 998  2023-05-28     ST03      PR001        10       17.06     CUST100
# 999  2023-09-06     ST02      PR020         7       99.74     CUST070
#
# [1000 rows x 6 columns]

# %%
sales_data['top_prod']=sales_data['Quantity']*sales_data['Unit_Price']
sales_prod_data=sales_data.groupby(['Store_ID','Product_ID'])['top_prod'].sum().reset_index()
top_sell=sales_prod_data.loc[sales_prod_data.groupby('Store_ID')['top_prod'].idxmax()]
top_sell
# Out:
#    Store_ID Product_ID  top_prod
# 16     ST01      PR017   4555.14
# 39     ST02      PR020   4462.93
# 44     ST03      PR005   5573.13
# 73     ST04      PR014   5727.43
# 81     ST05      PR002   5570.01

# %%
dic={'Name':'a',
     'class':'d'}

# %%
import pandas as pd

# Sample Products DataFrame
products = pd.DataFrame({
    'ProductID': [1, 2, 3, 4],
    'ProductName': ['Laptop', 'Phone', 'Chair', 'Table'],
    'Price': [800, 500, 150, 300],
    'Category': ['Electronics', 'Electronics', 'Furniture', 'Furniture']
})

# Sample Sales DataFrame
sales = pd.DataFrame({
    'SaleID': [1, 2, 3, 4],
    'ProductID': [1, 2, 3, 4],
    'QuantitySold': [5, 7, 10, 2]
})

# %%
# Merge the Products and Sales DataFrames
merged = pd.merge(products, sales, on='ProductID')

# %%
# Filter for Electronics Category
electronics = merged[merged['Category'] == 'Electronics']

# %%
merged
# Out:
#    ProductID ProductName  Price     Category  SaleID  QuantitySold
# 0          1      Laptop    800  Electronics       1             5
# 1          2       Phone    500  Electronics       2             7
# 2          3       Chair    150    Furniture       3            10
# 3          4       Table    300    Furniture       4             2

# %%
# Calculate Revenue (Price * QuantitySold)
electronics['Revenue'] = electronics['Price'] * electronics['QuantitySold']
# Out:
# <ipython-input-17-b167a132ecd3>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   electronics['Revenue'] = electronics['Price'] * electronics['QuantitySold']

# %%
products
# Out:
#    ProductID ProductName  Price     Category
# 0          1      Laptop    800  Electronics
# 1          2       Phone    500  Electronics
# 2          3       Chair    150    Furniture
# 3          4       Table    300    Furniture

# %%
# Filter for Products with Revenue > 3000
filtered_products = electronics[electronics['Revenue'] > 3000]

# Fetch Product Names
result = filtered_products['ProductName'].tolist()

print("Electronics products with revenue > 3000:", result)
# Out:
# Electronics products with revenue > 3000: ['Laptop', 'Phone']
